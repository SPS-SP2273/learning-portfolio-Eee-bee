# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# - generate high-quality, publication-ready plots using Python
# - packages that you can use to plot with python
#     - **Matplotlib (most popular and versatile)**
#     - Plotty
#     - Seaborn
#     - Bokeh
#     - Folium

# %%
conda install matplotlib -c conda-forge
# Out:
# 2 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/miniconda3
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-1.1.0               |       h1c43f85_4          20 KB  conda-forge
#     brotli-bin-1.1.0           |       h1c43f85_4          17 KB  conda-forge
#     contourpy-1.3.0            |  py313hc99daa9_2         256 KB  conda-forge
#     cycler-0.12.1              |     pyhd8ed1ab_1          13 KB  conda-forge
#     fonttools-4.59.2           |  py313h4db2fa4_0         2.7 MB  conda-forge
#     freetype-2.10.4            |       h4cff582_1         890 KB  conda-forge
#     jpeg-9e                    |       hb7f2c08_3         226 KB  conda-forge
#     kiwisolver-1.4.7           |  py313h0c4e38b_0          61 KB  conda-forge
#     lcms2-2.16                 |       h31d93a5_1         255 KB
#     lerc-4.0.0                 |       hb486fe8_0         284 KB  conda-forge
#     libbrotlicommon-1.1.0      |       h1c43f85_4          66 KB  conda-forge
#     libbrotlidec-1.1.0         |       h1c43f85_4          30 KB  conda-forge
#     libbrotlienc-1.1.0         |       h1c43f85_4         288 KB  conda-forge
#     libdeflate-1.22            |       h00291cd_0          69 KB  conda-forge
#     libpng-1.6.39              |       h6c40b1e_0         290 KB
#     libtiff-4.7.0              |       h2dfa3ea_0         436 KB
#     libwebp-base-1.6.0         |       hb807250_0         357 KB  conda-forge
#     matplotlib-3.10.0          |  py313habf4b1d_0          17 KB  conda-forge
#     matplotlib-base-3.10.0     |  py313hae83f4b_0         8.2 MB
#     munkres-1.1.4              |     pyhd8ed1ab_1          15 KB  conda-forge
#     openjpeg-2.5.2             |       h2d09ccc_1         350 KB
#     pillow-11.1.0              |  py313h935ef2f_1         938 KB
#     pyparsing-3.2.3            |     pyhe01879c_2         100 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        15.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotli             conda-forge/osx-64::brotli-1.1.0-h1c43f85_4
#   brotli-bin         conda-forge/osx-64::brotli-bin-1.1.0-h1c43f85_4
#   contourpy          conda-forge/osx-64::contourpy-1.3.0-py313hc99daa9_2
#   cycler             conda-forge/noarch::cycler-0.12.1-pyhd8ed1ab_1
#   fonttools          conda-forge/osx-64::fonttools-4.59.2-py313h4db2fa4_0
#   freetype           conda-forge/osx-64::freetype-2.10.4-h4cff582_1
#   jpeg               conda-forge/osx-64::jpeg-9e-hb7f2c08_3
#   kiwisolver         conda-forge/osx-64::kiwisolver-1.4.7-py313h0c4e38b_0
#   lcms2              pkgs/main/osx-64::lcms2-2.16-h31d93a5_1
#   lerc               conda-forge/osx-64::lerc-4.0.0-hb486fe8_0
#   libbrotlicommon    conda-forge/osx-64::libbrotlicommon-1.1.0-h1c43f85_4
#   libbrotlidec       conda-forge/osx-64::libbrotlidec-1.1.0-h1c43f85_4
#   libbrotlienc       conda-forge/osx-64::libbrotlienc-1.1.0-h1c43f85_4
#   libdeflate         conda-forge/osx-64::libdeflate-1.22-h00291cd_0
#   libpng             pkgs/main/osx-64::libpng-1.6.39-h6c40b1e_0
#   libtiff            pkgs/main/osx-64::libtiff-4.7.0-h2dfa3ea_0
#   libwebp-base       conda-forge/osx-64::libwebp-base-1.6.0-hb807250_0
#   matplotlib         conda-forge/osx-64::matplotlib-3.10.0-py313habf4b1d_0
#   matplotlib-base    pkgs/main/osx-64::matplotlib-base-3.10.0-py313hae83f4b_0
#   munkres            conda-forge/noarch::munkres-1.1.4-pyhd8ed1ab_1
#   openjpeg           pkgs/main/osx-64::openjpeg-2.5.2-h2d09ccc_1
#   pillow             pkgs/main/osx-64::pillow-11.1.0-py313h935ef2f_1
#   pyparsing          conda-forge/noarch::pyparsing-3.2.3-pyhe01879c_2
#
#
#
# Downloading and Extracting Packages:
# matplotlib-base-3.10 | 8.2 MB    |                                       |   0%
# fonttools-4.59.2     | 2.7 MB    |                                       |   0%
#
# pillow-11.1.0        | 938 KB    |                                       |   0%
#
#
# freetype-2.10.4      | 890 KB    |                                       |   0%
#
#
#
# libtiff-4.7.0        | 436 KB    |                                       |   0%
#
#
#
#
# libwebp-base-1.6.0   | 357 KB    |                                       |   0%
#
#
#
#
#
# openjpeg-2.5.2       | 350 KB    |                                       |   0%
#
#
#
#
#
#
# libpng-1.6.39        | 290 KB    |                                       |   0%
#
#
#
#
#
#
#
# libbrotlienc-1.1.0   | 288 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# lerc-4.0.0           | 284 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# contourpy-1.3.0      | 256 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 255 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 226 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# pyparsing-3.2.3      | 100 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.22      | 69 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlicommon-1.1. | 66 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# kiwisolver-1.4.7     | 61 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlidec-1.1.0   | 30 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-1.1.0         | 20 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-bin-1.1.0     | 17 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-3.10.0    | 17 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# munkres-1.1.4        | 15 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cycler-0.12.1        | 13 KB     |                                       |   0%
# fonttools-4.59.2     | 2.7 MB    | 2                                     |   1%
#
#
# matplotlib-base-3.10 | 8.2 MB    |                                       |   0%
#
# pillow-11.1.0        | 938 KB    | 6                                     |   2%
#
#
#
# libtiff-4.7.0        | 436 KB    | #3                                    |   4%
#
#
# freetype-2.10.4      | 890 KB    | ##################################### | 100%
# fonttools-4.59.2     | 2.7 MB    | ##################################### | 100%
#
#
#
# libtiff-4.7.0        | 436 KB    | ##################################### | 100%
#
# matplotlib-base-3.10 | 8.2 MB    | #############8                        |  37%
#
#
#
#
# libwebp-base-1.6.0   | 357 KB    | #6                                    |   4%
#
#
#
#
# libwebp-base-1.6.0   | 357 KB    | ##################################### | 100%
#
#
#
# libtiff-4.7.0        | 436 KB    | ##################################### | 100%
#
#
#
# libtiff-4.7.0        | 436 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 8.2 MB    | ####################################3 |  98%
#
#
#
#
#
#
#
#
# lerc-4.0.0           | 284 KB    | ##                                    |   6%
#
#
#
#
#
#
#
#
# lerc-4.0.0           | 284 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# libbrotlienc-1.1.0   | 288 KB    | ##################################### | 100%
#
#
#
#
#
#
# libpng-1.6.39        | 290 KB    | ##                                    |   6%
#
#
#
#
#
# openjpeg-2.5.2       | 350 KB    | #6                                    |   5%
#
#
#
#
#
#
# libpng-1.6.39        | 290 KB    | ##################################### | 100%
#
#
#
#
#
# matplotlib-base-3.10 | 8.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 255 KB    | ##3                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
# pyparsing-3.2.3      | 100 KB    | #####9                                |  16%
#
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 255 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# pyparsing-3.2.3      | 100 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 226 KB    | ##6                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 226 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlicommon-1.1. | 66 KB     | ########9                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlicommon-1.1. | 66 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.22      | 69 KB     | ########6                             |  23%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.22      | 69 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# contourpy-1.3.0      | 256 KB    | ##3                                   |   6%
#
#
#
#
#
#
#
#
#
# contourpy-1.3.0      | 256 KB    | ##################################### | 100%
#
#
# freetype-2.10.4      | 890 KB    | ##################################### | 100%
#
#
# freetype-2.10.4      | 890 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlidec-1.1.0   | 30 KB     | ###################7                  |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlidec-1.1.0   | 30 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-1.1.0         | 20 KB     | ##############################2       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-1.1.0         | 20 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-bin-1.1.0     | 17 KB     | ###################################   |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-bin-1.1.0     | 17 KB     | ##################################### | 100%
#
#
#
#
# libwebp-base-1.6.0   | 357 KB    | ##################################### | 100%
#
#
#
#
# libwebp-base-1.6.0   | 357 KB    | ##################################### | 100%
#
# pillow-11.1.0        | 938 KB    | ##################################### | 100%
#
# pillow-11.1.0        | 938 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# munkres-1.1.4        | 15 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cycler-0.12.1        | 13 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# munkres-1.1.4        | 15 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cycler-0.12.1        | 13 KB     | ##################################### | 100%
#
#
#
#
#
#
#
# libbrotlienc-1.1.0   | 288 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# libbrotlienc-1.1.0   | 288 KB    | ##################################### | 100%
#
#
#
#
#
#
# libpng-1.6.39        | 290 KB    | ##################################### | 100%
#
#
#
#
#
#
# libpng-1.6.39        | 290 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# lerc-4.0.0           | 284 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# lerc-4.0.0           | 284 KB    | ##################################### | 100%
#
#
#
#
#
# openjpeg-2.5.2       | 350 KB    | ##################################### | 100%
#
#
#
#
#
# openjpeg-2.5.2       | 350 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 255 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 255 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# pyparsing-3.2.3      | 100 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# pyparsing-3.2.3      | 100 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 226 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 226 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlicommon-1.1. | 66 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlicommon-1.1. | 66 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.22      | 69 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.22      | 69 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# kiwisolver-1.4.7     | 61 KB     | #########7                            |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-3.10.0    | 17 KB     | ###################################7  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-3.10.0    | 17 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# kiwisolver-1.4.7     | 61 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# contourpy-1.3.0      | 256 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# contourpy-1.3.0      | 256 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlidec-1.1.0   | 30 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlidec-1.1.0   | 30 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-1.1.0         | 20 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-1.1.0         | 20 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-bin-1.1.0     | 17 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# munkres-1.1.4        | 15 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cycler-0.12.1        | 13 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-3.10.0    | 17 KB     | ##################################### | 100%
# fonttools-4.59.2     | 2.7 MB    | ##################################### | 100%
# fonttools-4.59.2     | 2.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# kiwisolver-1.4.7     | 61 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # 1 A simple plot

# %% [markdown]
# ## 1.1 Let’s look at some code.

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_1, label='Y values',
         color='red', linestyle='dashed')
plt.xlabel('x-values') # x-axis name
plt.ylabel('y-values') # y-axis name
plt.title('X vs Y') # title
plt.grid(alpha=0.25) # opacity of the grid lines, 0 will mean no grid lines
plt.legend(loc='upper right') # location of legend

# %% [markdown]
# supported values for loc are 'best', 'upper right', 'upper left', 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 'upper center', 'center'
#
# 'bottom right' will not work

# %% [markdown]
# ### Things to note

# %% [markdown]
# #### Abbreviations
# |Long form|Abbreviation|
# |:--:|:--:|
# |colour|c|
# |linestyle|ls|
# |width|lw|

# %%
plt.plot(x, y_1, color='red', linestyle='dashed', linewidth=2)
# is the same as
plt.plot(x, y_1, c='red', ls='dashed', lw=2)

# %% [markdown]
# 1. From the above example:
#
#     Jupyter is an interactive environment, so you will see an output even if you omit plt.show(). However, it is good practice to include this line anyway so your code will also work in non-interactive environments (for instance, when the script is run directly from the command line).

# %% [markdown]
# 2. The plotting functions usually have default values for the styling parameters. So, if you wish, you can keep it simple and plot just using:

# %%
plt.plot(x, y_1, y_2) # default settings
# Out:
# [<matplotlib.lines.Line2D at 0x111c43610>,
#  <matplotlib.lines.Line2D at 0x111c43750>]

# %% [markdown]
# 3. You can split the arguments into separate lines to improve readability.
# So, both of the following forms are acceptable.

# %%
plt.plot(x, y_1, color='red', linestyle='dashed', linewidth=2)

# %%
plt.plot(x, y_2, label='Y values',
           color='red', linestyle='dashed')

# %% [markdown]
# 4. The order of how you specify the keyword arguments (color, linewidth, …) does not matter.

# %% [markdown]
# ## 1.2 Adding another plot

# %% [markdown]
# You can add another plot command to the graph to plot the data of y_2 in blue by adding the following line.

# %%
plt.plot(x, y_2,
         label='Y2 values', color='blue')

# %%
# both graphs
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Lets start plotting
plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed')
plt.plot(x, y_2, label='Y2 values', color='blue')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# ## 1.3 Yet another plot but with error bars

# %% [markdown]
# Let's include $x$ and $y$ error bars for the points.
#
# The plotting command to be used is called errorbar()

# %%
#basic format
plt.errorbar(x, y_3,
             xerr=x_error, yerr=y_error,
             label="Y3 with errors",
             color="green")

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75

# Lets start plotting
plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed',)
plt.plot(x, y_2, label='Y2 values', color='blue', )
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error,
             label='Y3 with errors', color='green')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# This example uses constant errors for all points. However, you can also provide a list of errors so that each will have a different length.

# %% [markdown]
# # 2 Better with NumPy

# %% [markdown]
# Often, it is easier to use NumPy arrays instead of Python lists. So, let’s first convert the Python lists into NumPy arrays and then redo the plot in the previous step.

# %%
import numpy as np

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

np_x = np.array(x)
np_y_1 = np.array(y_1)
np_y_2 = np.array(y_2)

plt.plot(np_x, np_y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(np_x, np_y_2, color='blue', label='Y2 values')

# %% [markdown]
# ## 2.1 Adding mathematical functions

# %% [markdown]
# One of the advantages of NumPy arrays is that they allow us to generate data-related mathematical functions easily. Let’s reuse our previous code to plot $x^2$ and $sin(x)$

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])

x2 = x**2                  # The math stuff
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',
         color='red', linestyle='dashed', )
plt.plot(x, sin_x, label='sin(x)',
         color='blue')
plt.legend() # default legend location

# %% [markdown]
# Sadly, our plot does not look good because and $sin(x)$ lies between $\pm$ 1, but $x^2$ has no such bounds. One way to fix this is to add another y-axis that shares the same x-axis.

# %% [markdown]
# ## We need another axis!

# %% [markdown]
# ### Things to note

# %% [markdown]
# Matplotlib offers a variety of ways to have multiple axes. The simplest way is to have another y-axis that shares the same x-axis. We can use the command twinx() for this.

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc='lower left')                                  # For y-axis 1

plt.twinx()                                                   # This creates a new y-axis 
                                                              # for the plots that comes after
plt.plot(x, sin_x, label='sin(x)',color='blue', )
plt.legend(loc='lower right')                                 # For y-axis 2

# %% [markdown]
# ### Things to note
#
# - We now have two legend() calls, one for each axis.
# - our plot still does not look good because we have only a few points. Let’s use np.linspace to fix this with:

# %%
x = np.linspace(0, 6, 100) # generates 100 evenly spaced numbers between
                           # 0 and 6

# %%
x2 = x**2
sin_x = np.sin(x)
plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc='lower left')                                  # For y-axis 1

plt.twinx()                                                   # This creates a new y-axis 
                                                              # for the plots that comes after
plt.plot(x, sin_x, label='sin(x)',color='blue', )
plt.legend(loc='lower right')

# %% [markdown]
# # 3 Saving to disc

# %% [markdown]
# If you want to use your plot in a report or presentation, you must first save it to disk. Luckily, Matplotlib makes it astonishingly easy to export plots into many formats (PDF, JPEG, PNG, BMP, etc.) and at different resolutions.
# - we need the function savefig()
# - we need to specify the format with the extension (e.g., filename.pdf)
# - We specify resolution by using dots-per-inch(dpi)

# %%
x = np.linspace(0, 6, 100)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',
         color='red', linestyle='dashed')
plt.legend(loc='lower left')
plt.twinx()
plt.plot(x, sin_x,
         label='sin x', color='blue')
plt.legend(loc='lower right')

plt.savefig('simple-plot.png', dpi=150)

# %% [markdown]
# When you run this code, you will find the file saved in the same directory (folder) as the one in your notebook lives in. If you want it saved elsewhere, specify the path in more detail.
#
# For example:

# %%
# plt.savefig('~/Desktop/simple-plot.png', dpi=150)

# %% [markdown]
# If you want the plot saved in JPEG format, you would use simple-plot.jpeg. Further, you can increase dpi if you want a higher resolution.

# %% [markdown]
# # 4 A real example: Global Warming

# %% [markdown]
# ## 4.1 Plotting data from files

# %% [markdown]
# Plotting data stored in a file (e.g., spreadsheet, text file, database) is a routine task for a scientist. In fact, the first thing you should do with any data is to look at it with a simple plot.
#
# For the rest of this section, we will use the Earth’s land temperature data from the Berkeley Earth website. Please visit the site (Global Warming Data Overview) and download the average temperature data for Daily Land. The original name of the file should be Complete_TAVG_daily.txt

# %%
data = np.loadtxt('Complete_TAVG_daily.txt',
                   skiprows=24)
date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.ylim([-8, 8]) # lowest and highest y-axis values

# %% [markdown]
# A small alpha value is used to soften the colour of the plot and made the plot range symmetrical in the $y$ direction.

# %% [markdown]
# Let’s add a horizontal line at the zero value to highlight the trend shown by the data. The hlines() function needs a $y$-value and starting and ending values for $x$

# %%
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')

# %% [markdown]
# format:
# plt.hlines($y$-value, starting $x$-value, ending $x$-value, linestyle, colour)

# %% [markdown]
# ## 4.2 Styles

# %% [markdown]
# Most people (very sensibly) might just want a decent-looking plot without spending time customising it. To facilitate this Matplotlib offers some standard style templates. We will use the one called *fivethirtyeight*.

# %%
plt.style.use('fivethirtyeight')

# %% [markdown]
# This line must be included right at the top of the code!

# %%
# completed code fir the global warming case study
plt.style.use('fivethirtyeight')

data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)

date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')
plt.ylim([-8, 8])

plt.xlabel('Date')
plt.ylabel('Temperature Anomaly')
plt.title('Temperature anomaly\n(Relative to  average from Jan 1951 - Dec 1980.)')

# %% [markdown]
# ### xkcd!

# %% [markdown]
# Okay, since we are talking about styles, the developers of Matplotlib have a healthy sense of humour and have included the option of making your plots in the xkcd style. To enable this, just run plt.xkcd() instead of setting a style.

# %% [markdown]
# ### Resetting styles

# %% [markdown]
# If you want to reset things and jump out of this style, you need to set the default style using:

# %%
plt.style.use('default')
